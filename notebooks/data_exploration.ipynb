# %%
#importing libraries 
import pandas as pd
import os

#Setting up the working directory 

#check the current directory 
print("Current: ", os.getcwd())

#change the directory 
data_path = os.path.join(notebook_dir, "..", "data", "raw")

os.chdir(data_path)

print("Dynamic Working Directory set to:", os.getcwd())


#loading the csv dataset 
df = pd.read_csv('customer_churn_business_dataset.csv')

#explore the imported data
print(df.head())
print(df.shape) #The total size of your dataset (Rows, Columns)
print(df.info()) #A detailed technical summary of the dataset
print(df.describe()) #Quick statistics for your numerical columns
print(df.isnull().sum()) # number of missing values on each column
# Out:
# Current:  /Users/manesh/Library/CloudStorage/OneDrive-UniversityofPlymouth/customer-churn-hybrid-xai/notebooks
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8 print("Current: ", os.getcwd())
#      10 #change the directory
# ---> 11 data_path = os.path.join(notebook_dir, "..", "data", "raw")
#      13 os.chdir(data_path)
#      15 print("Dynamic Working Directory set to:", os.getcwd())
#
# NameError: name 'notebook_dir' is not defined
