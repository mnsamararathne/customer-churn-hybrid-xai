# %%
# importing libraries 
import pandas as pd
import os

# Setting up the working directory 

# 1. Check and save the current notebook directory (THIS WAS MISSING!)
notebook_dir = os.getcwd()
print("Current folder:", notebook_dir)

# 2. change the directory dynamically
data_path = os.path.join(notebook_dir, "..", "data", "raw")
os.chdir(data_path)

print("Dynamic Working Directory set to:", os.getcwd())


#loading the csv dataset 
df = pd.read_csv('customer_churn_business_dataset.csv')

#explore the imported data
print(df.head())
print(df.shape) #The total size of your dataset (Rows, Columns)
print(df.info()) #A detailed technical summary of the dataset
print(df.describe()) #Quick statistics for your numerical columns
print(df.isnull().sum()) # number of missing values on each column
# Out:
# Current folder: /Users/manesh/Library/CloudStorage/OneDrive-UniversityofPlymouth/customer-churn-hybrid-xai/notebooks
# Dynamic Working Directory set to: /Users/manesh/Library/CloudStorage/OneDrive-UniversityofPlymouth/customer-churn-hybrid-xai/data/raw
#   customer_id  gender  age     country      city customer_segment  \
# 0  CUST_00001    Male   68  Bangladesh    London              SME
# 1  CUST_00002  Female   57      Canada    Sydney       Individual
# 2  CUST_00003    Male   24     Germany  New York              SME
# 3  CUST_00004    Male   49   Australia     Dhaka       Individual
# 4  CUST_00005    Male   65  Bangladesh     Delhi       Individual
#
#    tenure_months signup_channel contract_type  monthly_logins  ...  \
# 0             22            Web       Monthly              26  ...
# 1              9         Mobile       Monthly               7  ...
# 2             58            Web        Yearly              19  ...
# ...
